# %% [markdown]
# <a href="https://colab.research.google.com/github/janubro0125/Varsha-S-S-Machine-Learning/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Loan Approval.csv")
data
# Out:
#       Application_ID  Age  Annual_Income_INR  Credit_Score  Loan_Amount_INR  \
# 0          APP000001   58              53007           589           694512
# 1          APP000002   54              25672           710           994762
# 2          APP000003   31              48531           646          1063345
# 3          APP000004   32             116153           694           588217
# 4          APP000005   30              57430           699          1920917
# ...              ...  ...                ...           ...              ...
# 19995      APP019996   52              18423           702          2477889
# 19996      APP019997   61              76922           665           982460
# 19997      APP019998   63              80541           789           836261
# 19998      APP019999   59             128370           778           669894
# 19999      APP020000   40              20759           604          1678870
#
# ...

# %%
x=data[['Loan_Amount_INR']]
x
# Out:
#        Loan_Amount_INR
# 0               694512
# 1               994762
# 2              1063345
# 3               588217
# 4              1920917
# ...                ...
# 19995          2477889
# 19996           982460
# 19997           836261
# 19998           669894
# 19999          1678870
#
# [20000 rows x 1 columns]

# %%
y=data['Loan_Approved']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19995    0
# 19996    0
# 19997    1
# 19998    1
# 19999    0
# Name: Loan_Approved, Length: 20000, dtype: int64

# %%
model = LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
Loan_Amt=int(input("Enter youe loan amount:"))
iputss=[[Loan_Amt]]
print(model.predict(iputss))
# Out:
# Enter youe loan amount:588217
# [0]
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy*100)
# Out:
# Accuracy: 95.85000000000001

# %%
x_lines=np.linspace(300,850,100).reshape(-1,1)
y_prob=model.predict_proba(x_lines)[:,1]
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prob=accuracy_score(y_test,y_pred)
plt.scatter(data['Loan_Amount_INR'],data['Loan_Approved'])
plt.plot(x_lines,y_prob)
plt.show()
